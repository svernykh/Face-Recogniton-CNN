# %% [markdown]
# ## Tugas Besar Dep Learning
# # Face Recognition using Swin Transformer V2 Tiny
#
# Anggota kelompok:
# 1. Rayhan Fatih Gunawan
# 2. Muhammad Nelwan Fakhri
# 3. Raditya Erza Farandi
#
# Dalam jupyter notebook ini akan dilakukan tahapan preparasi dataset sampai evaluasi model yang telah difinetuned, dengan rincian sebagai berikut :
# 1. Import Library
# 2. Preparasi Dataset
# 3. Setup dan load model Swin Transformer V2 Tiny
# 4. Training loop
# 5. Evaluasi model
#
#
# ## Requirements
# - **Model**: Swin Transformer V2 Tiny (pretrained)
# - **Fine-tuning**: Freeze all layers except classifier and last two layers
# - **Epochs**: 12
# - **Batch Size**: 32
# - **Patience**: 3 (Early Stopping)
# - **Metrics**: Accuracy, Confusion Matrix

# %% [markdown]
# # Import library yang dibutuhkan
#
# Semua library yang dibutuhkan akan diimport di sini, list library ada di requirements.txt di root folder project, dengan rincian sebaga berikut :
# 1. pandas
# 2. numpy
# 3. matplotlib
# 4. seaborn
# 5. scikit-learn
# 6. ipykernel
# 7. torch
# 8. torchvision
# 9. torchaudio
# 10. pillow
# 11. tqdm

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms, models

# Check device and CUDA availability
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is NOT available. Running on CPU.")
    print("To fix this, you may need to reinstall PyTorch with CUDA support.")
    print("Run the following command in your terminal:")
    print("pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --force-reinstall")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# PyTorch Version: 2.5.1+cu121
# CUDA Available: True
# CUDA Version: 12.1
# Device Name: NVIDIA GeForce RTX 4050 Laptop GPU
# Using device: cuda

# %% [markdown]
# ## Configuration

# %%
CSV_FILE = 'dataset.csv'
DATA_DIR = 'Train'
BATCH_SIZE = 32
EPOCHS = 12
PATIENCE = 3
LEARNING_RATE = 0.001
IMG_SIZE = 256 # Swin Transformer V2 T (resolusi default)

# %% [markdown]
# ## Dataset Preparation

# %%
# Load CSV
df = pd.read_csv(CSV_FILE)

# Encode labels
label_map = {label: idx for idx, label in enumerate(df['label'].unique())}
idx_to_label = {idx: label for label, idx in label_map.items()}
df['label_idx'] = df['label'].map(label_map)

print(f"Total images: {len(df)}")
print(f"Total classes: {len(label_map)}")


train_df = df
val_df = df 

print(f"Train set: {len(train_df)}")
print(f"Val set: {len(val_df)}")
# Out:
# Total images: 270
# Total classes: 68
# Train set: 270
# Val set: 270

# %%
class FaceDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        img_name = row['gambar']
        label_name = row['label']
        label_idx = row['label_idx']
        
        # Construct full image path
        img_path = os.path.join(self.root_dir, label_name, img_name)
        
        try:
            image = Image.open(img_path).convert('RGB')
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a black image in case of error to prevent crash, or handle appropriately
            image = Image.new('RGB', (IMG_SIZE, IMG_SIZE))

        if self.transform:
            image = self.transform(image)

        return image, label_idx

# %%
# Augmentasi gambar
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Datasets & Loaders
train_dataset = FaceDataset(train_df, DATA_DIR, transform=train_transform)
val_dataset = FaceDataset(val_df, DATA_DIR, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# %% [markdown]
# # Visualisasi gambar setelah transform

# %%
# Visualize one image after transform
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Get a batch of training data
inputs, classes = next(iter(val_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs[:32])

plt.figure(figsize=(7, 7))
imshow(out, title=[idx_to_label[x.item()] for x in classes[:32]])

# %% [markdown]
# ## Model Setup

# %%
def get_model(num_classes):
    # Load Pretrained Swin Transformer V2 Tiny
    weights = models.Swin_V2_T_Weights.IMAGENET1K_V1
    model = models.swin_v2_t(weights=weights)
    
    # Freeze semua layer
    for param in model.parameters():
        param.requires_grad = False
        
    # Unfreeze layer terakhir dari features
    for param in model.features[-1].parameters():
        param.requires_grad = True
    for param in model.features[-2].parameters():
        param.requires_grad = True
        
    # Replace Head (Classifier)
    in_features = model.head.in_features
    model.head = nn.Sequential(
        nn.Dropout(p=0.3, inplace=True),
        nn.Linear(in_features, num_classes)
    )
    
    return model

model = get_model(len(label_map))
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/swin_v2_t-b137f0e2.pth" to C:\Users\acer/.cache\torch\hub\checkpoints\swin_v2_t-b137f0e2.pth
# 100%|██████████| 109M/109M [00:15<00:00, 7.18MB/s]

# %% [markdown]
# ## Training Loop

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=LEARNING_RATE)

# Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=3, min_delta=0): 
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    # Wrap loader with tqdm
    loop = tqdm(loader, desc='Training', leave=False)
    
    for images, labels in loop:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
        # Update progress bar
        loop.set_postfix(loss=loss.item())
        
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    # Wrap loader with tqdm
    loop = tqdm(loader, desc='Validation', leave=False)
    
    with torch.no_grad():
        for images, labels in loop:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# %%
early_stopper = EarlyStopping(patience=PATIENCE)
history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

print("Starting training...")
for epoch in range(EPOCHS):
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = validate(model, val_loader, criterion, device)
    
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    
    print(f"Epoch [{epoch+1}/{EPOCHS}] "
          f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")
    
    early_stopper(val_loss)
    if early_stopper.early_stop:
        print("Early stopping triggered")
        break

# Save model
torch.save(model.state_dict(), 'swin_v2_t_finetuned.pth')
print("Model saved.")
# Out:
# Starting training...
# Training:   0%|          | 0/9 [00:00<?, ?it/s]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  33%|███▎      | 3/9 [00:28<00:43,  7.25s/it, loss=4.28]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Validation:  56%|█████▌    | 5/9 [00:12<00:10,  2.61s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [1/12] Train Loss: 4.2556 Acc: 0.0370 | Val Loss: 3.7912 Acc: 0.4000
# Training:   0%|          | 0/9 [00:00<?, ?it/s]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Training:  67%|██████▋   | 6/9 [00:15<00:07,  2.66s/it, loss=2.66]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  78%|███████▊  | 7/9 [00:17<00:04,  2.43s/it, loss=3.27]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Validation:  56%|█████▌    | 5/9 [00:10<00:09,  2.36s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [2/12] Train Loss: 3.2415 Acc: 0.3148 | Val Loss: 1.1956 Acc: 0.7889
# Training:  56%|█████▌    | 5/9 [00:10<00:07,  1.97s/it, loss=1.79]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  78%|███████▊  | 7/9 [00:14<00:03,  1.99s/it, loss=0.948]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.10s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [3/12] Train Loss: 1.7377 Acc: 0.5963 | Val Loss: 0.3535 Acc: 0.9481
# Training:   0%|          | 0/9 [00:00<?, ?it/s]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Training:  56%|█████▌    | 5/9 [00:11<00:09,  2.29s/it, loss=0.666]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  78%|███████▊  | 7/9 [00:15<00:04,  2.13s/it, loss=0.483]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.07s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [4/12] Train Loss: 0.6420 Acc: 0.8630 | Val Loss: 0.0777 Acc: 0.9889
# Training:  11%|█         | 1/9 [00:02<00:18,  2.28s/it, loss=0.162]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  22%|██▏       | 2/9 [00:03<00:13,  1.88s/it, loss=0.408]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.15s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [5/12] Train Loss: 0.2354 Acc: 0.9556 | Val Loss: 0.0270 Acc: 0.9926
# Training:  44%|████▍     | 4/9 [00:07<00:09,  1.93s/it, loss=0.0921]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Training:  56%|█████▌    | 5/9 [00:10<00:08,  2.07s/it, loss=0.297]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  67%|██████▋   | 6/9 [00:12<00:06,  2.17s/it, loss=0.123]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.10s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [6/12] Train Loss: 0.1957 Acc: 0.9556 | Val Loss: 0.0147 Acc: 0.9963
# Training:  22%|██▏       | 2/9 [00:04<00:14,  2.07s/it, loss=0.0782]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Training:  44%|████▍     | 4/9 [00:09<00:11,  2.35s/it, loss=0.072]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  67%|██████▋   | 6/9 [00:13<00:06,  2.19s/it, loss=0.0317]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.07s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [7/12] Train Loss: 0.2133 Acc: 0.9370 | Val Loss: 0.0227 Acc: 0.9926
# EarlyStopping counter: 1 out of 3
# Training:  22%|██▏       | 2/9 [00:04<00:15,  2.15s/it, loss=0.0363]
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Training:  33%|███▎      | 3/9 [00:06<00:12,  2.11s/it, loss=0.152]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Training:  44%|████▍     | 4/9 [00:08<00:10,  2.01s/it, loss=0.126]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.09s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [8/12] Train Loss: 0.1430 Acc: 0.9778 | Val Loss: 0.0175 Acc: 0.9963
# EarlyStopping counter: 2 out of 3
# Training:  22%|██▏       | 2/9 [00:04<00:14,  2.14s/it, loss=0.116]
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Training:  44%|████▍     | 4/9 [00:07<00:10,  2.03s/it, loss=0.249]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Validation:  56%|█████▌    | 5/9 [00:09<00:08,  2.08s/it]
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
# Epoch [9/12] Train Loss: 0.1807 Acc: 0.9556 | Val Loss: 0.0151 Acc: 0.9963
# EarlyStopping counter: 3 out of 3
# Early stopping triggered
# Model saved.

# %% [markdown]
# ## Evaluation
#
# Evaluasi performa model menggunakan confussion matrix, accuracy, precision, recall, dan F1-score.

# %%
# Plot Training History
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], label='Train Acc')
plt.plot(history['val_acc'], label='Val Acc')
plt.legend()
plt.title('Accuracy')
plt.show()

# %%
# Confusion Matrix
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=list(label_map.keys()), yticklabels=list(label_map.keys()))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(all_labels, all_preds, target_names=list(label_map.keys())))
# Out:
# Error loading image Train\Lois Novel E Gurning\foto 3 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 3 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Lois Novel E Gurning\foto 4 - LOIS NOVEL E. GURNING.png: cannot identify image file 'Train\\Lois Novel E Gurning\\foto 4 - LOIS NOVEL E. GURNING.png'
# Error loading image Train\Martua Kevin A.M.H.Lubis\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg: [Errno 2] No such file or directory: 'Train\\Martua Kevin A.M.H.Lubis\\IMG_20241208_223409_653 - MARTUA KEVIN ANDREAS MUAL H LUBIS.jpg'
#                                  precision    recall  f1-score   support
#
#            Abraham Ganda Napitu       1.00      1.00      1.00         4
#        Abu Bakar Siddiq Siregar       1.00      1.00      1.00         4
#              Ahmad Faqih Hasani       1.00      1.00      1.00         4
#                    Aldi Sanjaya       1.00      1.00      1.00         4
#                         Alfajar       1.00      1.00      1.00         4
#             Alief Fathur Rahman       1.00      1.00      1.00         3
#  Arkan Hariz Chandrawinata Liem       1.00      1.00      1.00         4
#                Bayu Ega Ferdana       1.00      1.00      1.00         4
#           Bayu Prameswara Haris       1.00      1.00      1.00         4
#            Bezalel Samuel Manik       1.00      1.00      1.00         4
#            Bintang Fikri Fauzan       1.00      1.00      1.00         4
#               Boy Sandro Sigiro       1.00      1.00      1.00         4
#              Desty Ananta Purba       1.00      1.00      1.00         4
#           Dimas Azi Rajab Aizar       1.00      1.00      1.00         4
#               Dito Rifki Irawan       1.00      1.00      1.00         4
#             Dwi Arthur Revangga       1.00      1.00      1.00         4
#             Dyo Dwi Carol Bukit       1.00      1.00      1.00         4
#                     Eden Wijaya       1.00      1.00      1.00         4
